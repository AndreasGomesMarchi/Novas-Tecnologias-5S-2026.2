# %%
N = int(input("Digite um número: "))
ePrimo = True

for i in range(2, N):
    if N % i == 0:
        ePrimo = False

if ePrimo:
    print("É primo")
else:
    print("Não é primo")
# Out:
# Digite um número:  3
# É primo

# %% [markdown]
# ## Estruturas de Dados

# %%
#Lista
preco_carros = [12, 23, 12]

preco_carros.append(45) #Adicionando um novo valor no array

preco_carros.remove(preco_carros[2]) #Remover um valor de alguma posicao especifica do array

# %%
#Dicionario
carro1 = { 
    "Modelo" : "Monza",
    "Ano" : 1994,
    "preco" : 15000
}

carro2 = {
    "modelo" : "Kwid",
    "ano" : 2026,
    "preco" : 60000
}

print(carro2["ano"])
# Out:
# 2026

# %% [markdown]
# ## Função

# %%
taxa_financiamento = 10.15
qtd_parcelas = 48

valor_parcela_carro1 = (carro1['preco'] + (carro1['preco']*taxa_financiamento)) / qtd_parcelas

print(valor_parcela_carro1)
# Out:
# 3484.375
